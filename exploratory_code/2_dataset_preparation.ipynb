# %% [markdown]
# #                                                  Dataset Preparation
#
# Here we'll be removing nan's, normalizing numerical features, converting date features to numerical normalized features, and so on...

# %% [markdown]
# ## Importing the dataset

# %%
import pandas as pd
startups = pd.read_csv('data/startups_1_1.csv', index_col=0)
startups[:3]
# Out:
#                                             name  \
# /organization/-qounter                  :Qounter
# /organization/004-technologies  004 Technologies
# /organization/0xdata                      H2O.ai
#
#                                                      homepage_url  \
# /organization/-qounter                     http://www.qounter.com
# /organization/004-technologies  http://004gmbh.de/en/004-interact
# /organization/0xdata                               http://h2o.ai/
#
#                                                                     category_list  \
# /organization/-qounter          Application Platforms|Real Time|Social Network...
# /organization/004-technologies                                           Software
# /organization/0xdata                                                    Analytics
#
#                                funding_total_usd     status country_code  \
# /organization/-qounter                    700000  operating          USA
# /organization/004-technologies                 -  operating          USA
# /organization/0xdata                    33600000  operating          USA
#
#                                state_code                 region  \
# /organization/-qounter                 DE             DE - Other
# /organization/004-technologies         IL  Springfield, Illinois
# /organization/0xdata                   CA            SF Bay Area
#
#                                          city  funding_rounds  \
# /organization/-qounter          Delaware City               2
# /organization/004-technologies      Champaign               1
# /organization/0xdata            Mountain View               4
#
#                                             ...                \
# /organization/-qounter                      ...
# /organization/004-technologies              ...
# /organization/0xdata                        ...
#
#                                seed_funding_rounds  \
# /organization/-qounter                         1.0
# /organization/004-technologies                 0.0
# /organization/0xdata                           1.0
#
#                                undisclosed_funding_total_usd  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                undisclosed_funding_rounds  \
# /organization/-qounter                                0.0
# /organization/004-technologies                        0.0
# /organization/0xdata                                  0.0
#
#                                 venture_funding_total_usd  \
# /organization/-qounter                                0.0
# /organization/004-technologies                        0.0
# /organization/0xdata                           30600000.0
#
#                                 venture_funding_rounds  \
# /organization/-qounter                             0.0
# /organization/004-technologies                     0.0
# /organization/0xdata                               3.0
#
#                                 number_of_acquisitions  number_of_investments  \
# /organization/-qounter                             0.0                    0.0
# /organization/004-technologies                     0.0                    0.0
# /organization/0xdata                               0.0                    0.0
#
#                                 number_of_unique_investments  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                 number_of_investors_per_round  \
# /organization/-qounter                                    0.0
# /organization/004-technologies                            0.0
# /organization/0xdata                                      2.5
#
#                                 avg_amount_invested_per_round
# /organization/-qounter                                    0.0
# /organization/004-technologies                            0.0
# /organization/0xdata                                8400000.0
#
# [3 rows x 96 columns]

# %% [markdown]
# ## Droping some features
# We'll drop homepage_url, category_list, region, city, country_code
# We'll also move status to the end of the dataframe

# %%
#drop features
startups_dropped_features = startups.drop(['name','homepage_url', 'category_list', 'region', 'city', 'country_code'], 1)


#move status to the end
cols = list(startups_dropped_features)
cols.append(cols.pop(cols.index('status')))
startups_dropped_features = startups_dropped_features.ix[:, cols]

startups_dropped_features[:3]
# Out:
#                                funding_total_usd state_code  funding_rounds  \
# /organization/-qounter                    700000         DE               2
# /organization/004-technologies                 -         IL               1
# /organization/0xdata                    33600000         CA               4
#
#                                 founded_at first_funding_at last_funding_at  \
# /organization/-qounter          2014-09-04       2014-03-01      2014-10-14
# /organization/004-technologies  2010-01-01       2014-07-24      2014-07-24
# /organization/0xdata            2011-01-01       2013-01-03      2015-11-09
#
#                                 Category_Software  Category_Biotechnology  \
# /organization/-qounter                          0                       0
# /organization/004-technologies                  1                       0
# /organization/0xdata                            0                       0
#
#                                 Category_Mobile  Category_Enterprise Software  \
# /organization/-qounter                        0                             0
# /organization/004-technologies                0                             0
# /organization/0xdata                          0                             0
#
#                                   ...      undisclosed_funding_total_usd  \
# /organization/-qounter            ...                                0.0
# /organization/004-technologies    ...                                0.0
# /organization/0xdata              ...                                0.0
#
#                                 undisclosed_funding_rounds  \
# /organization/-qounter                                 0.0
# /organization/004-technologies                         0.0
# /organization/0xdata                                   0.0
#
#                                 venture_funding_total_usd  \
# /organization/-qounter                                0.0
# /organization/004-technologies                        0.0
# /organization/0xdata                           30600000.0
#
#                                 venture_funding_rounds  \
# /organization/-qounter                             0.0
# /organization/004-technologies                     0.0
# /organization/0xdata                               3.0
#
#                                 number_of_acquisitions  number_of_investments  \
# /organization/-qounter                             0.0                    0.0
# /organization/004-technologies                     0.0                    0.0
# /organization/0xdata                               0.0                    0.0
#
#                                 number_of_unique_investments  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                 number_of_investors_per_round  \
# /organization/-qounter                                    0.0
# /organization/004-technologies                            0.0
# /organization/0xdata                                      2.5
#
#                                 avg_amount_invested_per_round     status
# /organization/-qounter                                    0.0  operating
# /organization/004-technologies                            0.0  operating
# /organization/0xdata                                8400000.0  operating
#
# [3 rows x 90 columns]

# %% [markdown]
# ## Normalizing numeric variables

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

startups_normalized = startups_dropped_features.copy()

#Convert '-' to zeros in funding_total_usd
startups_normalized['funding_total_usd'] = startups_normalized['funding_total_usd'].replace('-', 0)

columns_to_scale = list(startups_normalized.filter(regex=(".*(funding_rounds|funding_total_usd)|(number_of|avg_).*")).columns)
startups_normalized[columns_to_scale] = min_max_scaler.fit_transform(startups_normalized[columns_to_scale])
startups_normalized[:3]
# Out:
#                                 funding_total_usd state_code  funding_rounds  \
# /organization/-qounter                   0.000023         DE        0.055556
# /organization/004-technologies           0.000000         IL        0.000000
# /organization/0xdata                     0.001117         CA        0.166667
#
#                                 founded_at first_funding_at last_funding_at  \
# /organization/-qounter          2014-09-04       2014-03-01      2014-10-14
# /organization/004-technologies  2010-01-01       2014-07-24      2014-07-24
# /organization/0xdata            2011-01-01       2013-01-03      2015-11-09
#
#                                 Category_Software  Category_Biotechnology  \
# /organization/-qounter                          0                       0
# /organization/004-technologies                  1                       0
# /organization/0xdata                            0                       0
#
#                                 Category_Mobile  Category_Enterprise Software  \
# /organization/-qounter                        0                             0
# /organization/004-technologies                0                             0
# /organization/0xdata                          0                             0
#
#                                   ...      undisclosed_funding_total_usd  \
# /organization/-qounter            ...                                0.0
# /organization/004-technologies    ...                                0.0
# /organization/0xdata              ...                                0.0
#
#                                 undisclosed_funding_rounds  \
# /organization/-qounter                                 0.0
# /organization/004-technologies                         0.0
# /organization/0xdata                                   0.0
#
#                                 venture_funding_total_usd  \
# /organization/-qounter                           0.000000
# /organization/004-technologies                   0.000000
# /organization/0xdata                             0.001739
#
#                                 venture_funding_rounds  \
# /organization/-qounter                        0.000000
# /organization/004-technologies                0.000000
# /organization/0xdata                          0.214286
#
#                                 number_of_acquisitions  number_of_investments  \
# /organization/-qounter                             0.0                    0.0
# /organization/004-technologies                     0.0                    0.0
# /organization/0xdata                               0.0                    0.0
#
#                                 number_of_unique_investments  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                 number_of_investors_per_round  \
# /organization/-qounter                               0.000000
# /organization/004-technologies                       0.000000
# /organization/0xdata                                 0.104167
#
#                                 avg_amount_invested_per_round     status
# /organization/-qounter                               0.000000  operating
# /organization/004-technologies                       0.000000  operating
# /organization/0xdata                                 0.000477  operating
#
# [3 rows x 90 columns]

# %% [markdown]
# ## Normalizing date variables

# %%
from datetime import datetime
from dateutil import relativedelta



def date_to_age_in_months(date):
    if date != date or date == 0: #is NaN
        return 0
    date1 = datetime.strptime(date, '%Y-%m-%d')
    date2 = datetime.strptime('2017-01-01', '%Y-%m-%d') #get age until 01/01/2017
    delta =  relativedelta.relativedelta(date2, date1)
    return delta.years * 12 + delta.months
    
    
startups_dates_normalized = startups_normalized.copy()
startups_dates_normalized['founded_at'] = startups_dates_normalized['founded_at'].map(date_to_age_in_months)
startups_dates_normalized['first_funding_at'] = startups_dates_normalized['first_funding_at'].map(date_to_age_in_months)
startups_dates_normalized['last_funding_at'] = startups_dates_normalized['last_funding_at'].map(date_to_age_in_months)

startups_dates_normalized[:3]
# Out:
#                                 funding_total_usd state_code  funding_rounds  \
# /organization/-qounter                   0.000023         DE        0.055556
# /organization/004-technologies           0.000000         IL        0.000000
# /organization/0xdata                     0.001117         CA        0.166667
#
#                                 founded_at  first_funding_at  last_funding_at  \
# /organization/-qounter                  27                34               26
# /organization/004-technologies          84                29               29
# /organization/0xdata                    72                47               13
#
#                                 Category_Software  Category_Biotechnology  \
# /organization/-qounter                          0                       0
# /organization/004-technologies                  1                       0
# /organization/0xdata                            0                       0
#
#                                 Category_Mobile  Category_Enterprise Software  \
# /organization/-qounter                        0                             0
# /organization/004-technologies                0                             0
# /organization/0xdata                          0                             0
#
#                                   ...      undisclosed_funding_total_usd  \
# /organization/-qounter            ...                                0.0
# /organization/004-technologies    ...                                0.0
# /organization/0xdata              ...                                0.0
#
#                                 undisclosed_funding_rounds  \
# /organization/-qounter                                 0.0
# /organization/004-technologies                         0.0
# /organization/0xdata                                   0.0
#
#                                 venture_funding_total_usd  \
# /organization/-qounter                           0.000000
# /organization/004-technologies                   0.000000
# /organization/0xdata                             0.001739
#
#                                 venture_funding_rounds  \
# /organization/-qounter                        0.000000
# /organization/004-technologies                0.000000
# /organization/0xdata                          0.214286
#
#                                 number_of_acquisitions  number_of_investments  \
# /organization/-qounter                             0.0                    0.0
# /organization/004-technologies                     0.0                    0.0
# /organization/0xdata                               0.0                    0.0
#
#                                 number_of_unique_investments  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                 number_of_investors_per_round  \
# /organization/-qounter                               0.000000
# /organization/004-technologies                       0.000000
# /organization/0xdata                                 0.104167
#
#                                 avg_amount_invested_per_round     status
# /organization/-qounter                               0.000000  operating
# /organization/004-technologies                       0.000000  operating
# /organization/0xdata                                 0.000477  operating
#
# [3 rows x 90 columns]

# %%
startups_dates_normalized[['founded_at', 'first_funding_at', 'last_funding_at']] = min_max_scaler.fit_transform(startups_dates_normalized[['founded_at', 'first_funding_at', 'last_funding_at']])
startups_dates_normalized[:3]
# Out:
#                                 funding_total_usd state_code  funding_rounds  \
# /organization/-qounter                   0.000023         DE        0.055556
# /organization/004-technologies           0.000000         IL        0.000000
# /organization/0xdata                     0.001117         CA        0.166667
#
#                                 founded_at  first_funding_at  last_funding_at  \
# /organization/-qounter            0.005917          0.002825         0.027344
# /organization/004-technologies    0.018409          0.002410         0.033203
# /organization/0xdata              0.015779          0.003906         0.001953
#
#                                 Category_Software  Category_Biotechnology  \
# /organization/-qounter                          0                       0
# /organization/004-technologies                  1                       0
# /organization/0xdata                            0                       0
#
#                                 Category_Mobile  Category_Enterprise Software  \
# /organization/-qounter                        0                             0
# /organization/004-technologies                0                             0
# /organization/0xdata                          0                             0
#
#                                   ...      undisclosed_funding_total_usd  \
# /organization/-qounter            ...                                0.0
# /organization/004-technologies    ...                                0.0
# /organization/0xdata              ...                                0.0
#
#                                 undisclosed_funding_rounds  \
# /organization/-qounter                                 0.0
# /organization/004-technologies                         0.0
# /organization/0xdata                                   0.0
#
#                                 venture_funding_total_usd  \
# /organization/-qounter                           0.000000
# /organization/004-technologies                   0.000000
# /organization/0xdata                             0.001739
#
#                                 venture_funding_rounds  \
# /organization/-qounter                        0.000000
# /organization/004-technologies                0.000000
# /organization/0xdata                          0.214286
#
#                                 number_of_acquisitions  number_of_investments  \
# /organization/-qounter                             0.0                    0.0
# /organization/004-technologies                     0.0                    0.0
# /organization/0xdata                               0.0                    0.0
#
#                                 number_of_unique_investments  \
# /organization/-qounter                                   0.0
# /organization/004-technologies                           0.0
# /organization/0xdata                                     0.0
#
#                                 number_of_investors_per_round  \
# /organization/-qounter                               0.000000
# /organization/004-technologies                       0.000000
# /organization/0xdata                                 0.104167
#
#                                 avg_amount_invested_per_round     status
# /organization/-qounter                               0.000000  operating
# /organization/004-technologies                       0.000000  operating
# /organization/0xdata                                 0.000477  operating
#
# [3 rows x 90 columns]

# %% [markdown]
# ## Analzying types of status

# %%
startups_dates_normalized['status'].unique()
# Out:
# array(['operating', 'acquired', 'closed', 'ipo'], dtype=object)

# %%
startups_dates_normalized['status'].value_counts()
# Out:
# operating    29429
# acquired      4156
# closed        2907
# ipo           1109
# Name: status, dtype: int64

# %% [markdown]
# ## Saved prepared database to csv

# %%
startups_dates_normalized.to_csv('data/startups_2.csv')
